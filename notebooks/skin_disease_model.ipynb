# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

train_df = pd.read_csv('/content/drive/MyDrive/skin-disease-detection-cnn/data/preprocessed/train.csv')
val_df = pd.read_csv('/content/drive/MyDrive/skin-disease-detection-cnn/data/preprocessed/val.csv')
test_df = pd.read_csv('/content/drive/MyDrive/skin-disease-detection-cnn/data/preprocessed/test.csv')
print(train_df.shape)
print(val_df.shape)
print(test_df.shape)
# Out:
# (6981, 10)
# (1518, 10)
# (1516, 10)

# %%
import shutil
shutil.copy(
    '/content/drive/MyDrive/skin-disease-detection-cnn/app/utils.py',
    '/content/utils.py'
)

import sys
sys.path.append('/content')

from utils import get_image_path, get_generators
print("Utils imported successfully!")
# Out:
# Utils imported successfully!

# %%
train_generator, val_generator, test_generator = get_generators(train_df, val_df, test_df)
# Out:
# Found 6981 validated image filenames.
# Found 1518 validated image filenames.
# Found 1516 validated image filenames.
